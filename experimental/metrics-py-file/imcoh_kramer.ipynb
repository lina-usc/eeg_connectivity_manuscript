# %%
import mne
from mne.coreg import Coregistration
from mne.minimum_norm import make_inverse_operator, apply_inverse_epochs
import numpy as np
from pathlib import Path
import pandas as pd
import os
from pathlib import Path
from mne_connectivity import spectral_connectivity_epochs
import xarray as xr
import time
from spectral_connectivity import Multitaper, Connectivity
import gc

# %%
def filter_labels_with_vertices(labels_parc, src):
    # Get the vertices from both hemispheres in the source space
    src_vertices = [src[0]['vertno'], src[1]['vertno']]
    
    # Initialize an empty list to hold valid labels
    valid_labels = []
    
    for label in labels_parc:
        # Determine the hemisphere index: 0 for 'lh' and 1 for 'rh'
        hemi_idx = 0 if label.hemi == 'lh' else 1
        
        # Check if any of the label's vertices are in the source space for that hemisphere
        if any(v in src_vertices[hemi_idx] for v in label.vertices):
            valid_labels.append(label)
            
    return valid_labels

# %%
subjects_dir = "/Users/lina_01/Desktop/repos/Connectivity_EEG_benchmarking/inspected"
#subjects_dir = "/scratch/MPI-LEMON/freesurfer/subjects/inspected"
#subjects = ["sub-032302"]
subjects = [subject for subject in os.listdir(subjects_dir) if subject.startswith('sub')]
#subjects_complete = [subject.split("_")[0] for subject in os.listdir("imcoh_results")]
#remaining_subjects = [subject for subject in subjects if subject not in subjects_complete]
conditions = ['EC','EO']

# %%
start_time = time.time()

for subject in remaining_subjects:
    try:
        conditions_mats = []
        for condition in conditions:
            src = mne.setup_source_space(subject, add_dist="patch", subjects_dir=subjects_dir)
            #raw = mne.io.read_raw_eeglab(f"/Users/lina_01/Desktop/eeg/{subject}/{subject}_{condition}.set")
            raw = mne.io.read_raw_eeglab(f"/scratch/MPI-LEMON/freesurfer/subjects/eeg/{subject}/{subject}_{condition}.set")
            
            info = raw.info
            fiducials = "estimated"
            coreg = Coregistration(info, subject, subjects_dir, fiducials=fiducials)
            
            conductivity = (0.3, 0.006, 0.3)
            model = mne.make_bem_model(subject=subject, conductivity=conductivity, subjects_dir=subjects_dir)
            bem = mne.make_bem_solution(model)
            
            epochs = mne.make_fixed_length_epochs(raw, duration=1.0, preload=False)
            epochs.set_eeg_reference(projection=True)
            epochs.apply_baseline((None,None))
            fwd = mne.make_forward_solution(
                epochs.info, trans=coreg.trans, src=src, bem=bem, verbose=True
            )
            
            cov = mne.compute_covariance(epochs)
            
            inv = mne.minimum_norm.make_inverse_operator(epochs.info, fwd, cov, verbose=True)
            
            method = "sLORETA"
            snr = 3.0
            lambda2 = 1.0 / snr**2
            stc = apply_inverse_epochs(
                epochs,
                inv,
                lambda2,
                method=method,
                pick_ori=None,
                verbose=True,
                return_generator=False
            )
            
            labels_parc = mne.read_labels_from_annot(subject, parc='aparc', subjects_dir=subjects_dir)
            
            filtered_labels = filter_labels_with_vertices(labels_parc, src)
            label_ts = mne.extract_label_time_course(stc, filtered_labels, src, mode='auto', return_generator=False, allow_empty=False)
            
            n=len(epochs)
    
            mats=[]
            
            for i in range(100):
                inds = np.random.choice(range(n),int(n/2),replace=False)
                m = Multitaper(time_series=np.array(label_ts)[inds].transpose(2, 0, 1),
                    sampling_frequency=250)
                
                c = Connectivity(fourier_coefficients=m.fft(),
                        frequencies=m.frequencies,
                        time=m.time)    
                
                con = getattr(c, 'generalized_partial_directed_coherence')()
                mat = np.nan_to_num(con.squeeze())
                mats.append(mat[8:14,:,:])
                frequencies = c.frequencies
                del m
                del c
                del con
                gc.collect()
    
            region = [label.name for label in filtered_labels]
            frequencies = list(frequencies[8:14])
            bootstrap_samples = list(range(100))
    
            xarray = xr.DataArray(np.array(mats), dims=["bootstrap_samples","frequencies","region1","region2"],
                                  coords={"bootstrap_samples":bootstrap_samples,"frequencies":frequencies,"region1":region, "region2":region})
            xarray.to_netcdf(f'imcoh_results/{subject}_array_imcoh_{condition}.nc')
            
    except Exception as e:
        print(f'failed on {subject}')
        print(e)
        continue

print(time.time()-start_time)
# Out:
# Setting up the source space with the following parameters:
#
# SUBJECTS_DIR = /Users/lina_01/Desktop
# Subject      = sub-032302
# Surface      = white
# Octahedron subdivision grade 6
#
# >>> 1. Creating the source space...
#
# Doing the octahedral vertex picking...
# Loading /Users/lina_01/Desktop/sub-032302/surf/lh.white...
# Mapping lh sub-032302 -> oct (6) ...
#     Triangle neighbors and vertex normals...
# Loading geometry from /Users/lina_01/Desktop/sub-032302/surf/lh.sphere...
# Setting up the triangulation for the decimated surface...
# loaded lh.white 4098/125183 selected to source space (oct = 6)
#
# Loading /Users/lina_01/Desktop/sub-032302/surf/rh.white...
# Mapping rh sub-032302 -> oct (6) ...
#     Triangle neighbors and vertex normals...
# Loading geometry from /Users/lina_01/Desktop/sub-032302/surf/rh.sphere...
# Setting up the triangulation for the decimated surface...
# loaded rh.white 4098/126579 selected to source space (oct = 6)
#
# Calculating patch information (limit=0.0 mm)...
#     Computing patch statistics...
#     Patch information added...
#     Computing patch statistics...
#     Patch information added...
# You are now one step closer to computing the gain matrix
# Reading /Users/lina_01/Desktop/eeg/sub-032302/sub-032302_EC.fdt
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /Users/lina_01/Desktop/sub-032302/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Creating the BEM geometry...
# Going from 5th to 4th subdivision of an icosahedron (n_tri: 20480 -> 5120)
# /var/folders/cl/8cj5mvt51nbchvsgng871t400000gn/T/ipykernel_1581/3649947725.py:9: RuntimeWarning: Data file name in EEG.data (sub-010003_EC.fdt) is incorrect, the file name must have changed on disk, using the correct file name (sub-032302_EC.fdt).
#   raw = mne.io.read_raw_eeglab(f"/Users/lina_01/Desktop/eeg/{subject}/{subject}_{condition}.set")
# /var/folders/cl/8cj5mvt51nbchvsgng871t400000gn/T/ipykernel_1581/3649947725.py:9: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_eeglab(f"/Users/lina_01/Desktop/eeg/{subject}/{subject}_{condition}.set")
# /var/folders/cl/8cj5mvt51nbchvsgng871t400000gn/T/ipykernel_1581/3649947725.py:9: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(f"/Users/lina_01/Desktop/eeg/{subject}/{subject}_{condition}.set")
# Going from 5th to 4th subdivision of an icosahedron (n_tri: 20480 -> 5120)
# Going from 5th to 4th subdivision of an icosahedron (n_tri: 20480 -> 5120)
# outer skin  CM is   0.81 -10.23  24.94 mm
# outer skull CM is   0.80 -10.13  24.44 mm
# inner skull CM is   0.79 -12.40  34.37 mm
# Checking that surface outer skull is inside surface outer skin  ...
# Checking that surface inner skull is inside surface outer skull ...
# Checking distance between outer skin  and outer skull surfaces...
# Minimum distance between the outer skin  and outer skull surfaces is approximately    1.8 mm
# Checking distance between outer skull and inner skull surfaces...
# Minimum distance between the outer skull and inner skull surfaces is approximately    1.2 mm
# Surfaces passed the basic topology checks.
# Complete.
#
# Three-layer model surfaces loaded.
# Computing the linear collocation solution...
#     Matrix coefficients...
#         outer skin  (2562) -> outer skin  (2562) ...
#         outer skin  (2562) -> outer skull (2562) ...
#         outer skin  (2562) -> inner skull (2562) ...
#         outer skull (2562) -> outer skin  (2562) ...
#         outer skull (2562) -> outer skull (2562) ...
#         outer skull (2562) -> inner skull (2562) ...
#         inner skull (2562) -> outer skin  (2562) ...
#         inner skull (2562) -> outer skull (2562) ...
#         inner skull (2562) -> inner skull (2562) ...
#     Inverting the coefficient matrix...
# IP approach required...
#     Matrix coefficients (homog)...
#         inner skull (2562) -> inner skull (2562) ...
#     Inverting the coefficient matrix (homog)...
#     Modify the original solution to incorporate IP approach...
#         Combining...
#         Scaling...
# Solution ready.
# BEM geometry computations complete.
# Not setting metadata
# 478 matching events found
# No baseline correction applied
# 0 projection items activated
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Applying baseline correction (mode: mean)
# Source space          : <SourceSpaces: [<surface (lh), n_vertices=125183, n_used=4098>, <surface (rh), n_vertices=126579, n_used=4098>] MRI (surface RAS) coords, subject 'sub-032302', ~24.3 MB>
# MRI -> head transform : instance of Transform
# Measurement data      : instance of Info
# Conductor model   : instance of ConductorModel
# Accurate field computations
# Do computations in head coordinates
# Free source orientations
#
# Read 2 source spaces a total of 8196 active source locations
#
# Coordinate transformation: MRI (surface RAS) -> head
#      1.000000  0.000000  0.000000       0.00 mm
#      0.000000  1.000000  0.000000       0.00 mm
#      0.000000  0.000000  1.000000       0.00 mm
#      0.000000  0.000000  0.000000       1.00
#
# Read  60 EEG channels from info
# Head coordinate coil definitions created.
# Source spaces are now in head coordinates.
#
# Employing the head->MRI coordinate transform with the BEM model.
# BEM model instance of ConductorModel is now set up
#
# Source spaces are in head coordinates.
# Checking that the sources are inside the surface (will take a few...)
# Checking surface interior status for 4098 points...
#     Found  863/4098 points inside  an interior sphere of radius   40.8 mm
#     Found    0/4098 points outside an exterior sphere of radius   91.3 mm
#     Found    0/3235 points outside using surface Qhull
#     Found    0/3235 points outside using solid angles
#     Total 4098/4098 points inside the surface
# Interior check completed in 2021.9 ms
# Checking surface interior status for 4098 points...
#     Found  892/4098 points inside  an interior sphere of radius   40.8 mm
#     Found    0/4098 points outside an exterior sphere of radius   91.3 mm
#     Found    0/3206 points outside using surface Qhull
#     Found    0/3206 points outside using solid angles
#     Total 4098/4098 points inside the surface
# Interior check completed in 1976.7 ms
#
# Setting up for EEG...
# Computing EEG at 8196 source locations (free orientations)...
#
# Finished.
# Loading data for 478 events and 250 original time points ...
# 0 bad epochs dropped
# Computing rank from data with rank=None
#     Using tolerance 2.4e-10 (2.2e-16 eps * 60 dim * 1.8e+04  max singular value)
#     Estimated rank (eeg): 59
#     EEG: rank 59 computed from 60 data channels with 1 projector
#     Created an SSP operator (subspace dimension = 1)
#     Setting small EEG eigenvalues to zero (without PCA)
# Reducing data rank from 60 -> 59
# Estimating covariance using EMPIRICAL
# Done.
# Number of samples used : 119500
# [done]
# Converting forward solution to surface orientation
#     Average patch normals will be employed in the rotation to the local surface coordinates....
#     Converting to surface-based source orientations...
#     [done]
# Computing inverse operator with 60 channels.
#     60 out of 60 channels remain after picking
# Selected 60 channels
# Creating the depth weighting matrix...
#     60 EEG channels
#     limit = 8197/8196 = 4.001528
#     scale = 234572 exp = 0.8
# Applying loose dipole orientations to surface source spaces: 0.2
# Whitening the forward solution.
#     Created an SSP operator (subspace dimension = 1)
# Computing rank from covariance with rank=None
#     Using tolerance 4.2e-13 (2.2e-16 eps * 60 dim * 32  max singular value)
#     Estimated rank (eeg): 26
#     EEG: rank 26 computed from 60 data channels with 1 projector
#     Setting small EEG eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing SVD of whitened and weighted lead field matrix.
#     largest singular value = 3.47026
#     scaling factor to adjust the trace = 3.96004e+19 (nchan = 60 nzero = 34)
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 1
#     Created the regularized inverter
#     Created an SSP operator (subspace dimension = 1)
#     Created the whitener using a noise covariance matrix with rank 26 (34 small eigenvalues omitted)
#     Computing noise-normalization factors (sLORETA)...
# [done]
# Picked 60 channels from the data
# Computing inverse...
#     Eigenleads need to be weighted ...
# Processing epoch : 1 / 478
# combining the current components...
# Processing epoch : 2 / 478
# combining the current components...
# Processing epoch : 3 / 478
# combining the current components...
# Processing epoch : 4 / 478
# combining the current components...
# Processing epoch : 5 / 478
# combining the current components...
# Processing epoch : 6 / 478
# combining the current components...
# Processing epoch : 7 / 478
# combining the current components...
# Processing epoch : 8 / 478
# combining the current components...
# Processing epoch : 9 / 478
# combining the current components...
# Processing epoch : 10 / 478
# combining the current components...
# Processing epoch : 11 / 478
# combining the current components...
# Processing epoch : 12 / 478
# combining the current components...
# Processing epoch : 13 / 478
# combining the current components...
# Processing epoch : 14 / 478
# combining the current components...
# Processing epoch : 15 / 478
# combining the current components...
# Processing epoch : 16 / 478
# combining the current components...
# Processing epoch : 17 / 478
# combining the current components...
# Processing epoch : 18 / 478
# combining the current components...
# Processing epoch : 19 / 478
# combining the current components...
# Processing epoch : 20 / 478
# combining the current components...
# Processing epoch : 21 / 478
# combining the current components...
# Processing epoch : 22 / 478
# combining the current components...
# Processing epoch : 23 / 478
# combining the current components...
# Processing epoch : 24 / 478
# combining the current components...
# Processing epoch : 25 / 478
# combining the current components...
# Processing epoch : 26 / 478
# combining the current components...
# Processing epoch : 27 / 478
# combining the current components...
# Processing epoch : 28 / 478
# combining the current components...
# Processing epoch : 29 / 478
# combining the current components...
# Processing epoch : 30 / 478
# combining the current components...
# Processing epoch : 31 / 478
# combining the current components...
# Processing epoch : 32 / 478
# combining the current components...
# Processing epoch : 33 / 478
# combining the current components...
# Processing epoch : 34 / 478
# combining the current components...
# Processing epoch : 35 / 478
# combining the current components...
# Processing epoch : 36 / 478
# combining the current components...
# Processing epoch : 37 / 478
# combining the current components...
# Processing epoch : 38 / 478
# combining the current components...
# Processing epoch : 39 / 478
# combining the current components...
# Processing epoch : 40 / 478
# combining the current components...
# Processing epoch : 41 / 478
# combining the current components...
# Processing epoch : 42 / 478
# combining the current components...
# Processing epoch : 43 / 478
# combining the current components...
# Processing epoch : 44 / 478
# combining the current components...
# Processing epoch : 45 / 478
# combining the current components...
# Processing epoch : 46 / 478
# combining the current components...
# Processing epoch : 47 / 478
# combining the current components...
# Processing epoch : 48 / 478
# combining the current components...
# Processing epoch : 49 / 478
# combining the current components...
# Processing epoch : 50 / 478
# combining the current components...
# Processing epoch : 51 / 478
# combining the current components...
# Processing epoch : 52 / 478
# combining the current components...
# Processing epoch : 53 / 478
# combining the current components...
# Processing epoch : 54 / 478
# combining the current components...
# Processing epoch : 55 / 478
# combining the current components...
# Processing epoch : 56 / 478
# combining the current components...
# Processing epoch : 57 / 478
# combining the current components...
# Processing epoch : 58 / 478
# combining the current components...
# Processing epoch : 59 / 478
# combining the current components...
# Processing epoch : 60 / 478
# combining the current components...
# Processing epoch : 61 / 478
# combining the current components...
# Processing epoch : 62 / 478
# combining the current components...
# Processing epoch : 63 / 478
# combining the current components...
# Processing epoch : 64 / 478
# combining the current components...
# Processing epoch : 65 / 478
# combining the current components...
# Processing epoch : 66 / 478
# combining the current components...
# Processing epoch : 67 / 478
# combining the current components...
# Processing epoch : 68 / 478
# combining the current components...
# Processing epoch : 69 / 478
# combining the current components...
# Processing epoch : 70 / 478
# combining the current components...
# Processing epoch : 71 / 478
# combining the current components...
# Processing epoch : 72 / 478
# combining the current components...
# Processing epoch : 73 / 478
# combining the current components...
# Processing epoch : 74 / 478
# combining the current components...
# Processing epoch : 75 / 478
# combining the current components...
# Processing epoch : 76 / 478
# combining the current components...
# Processing epoch : 77 / 478
# combining the current components...
# Processing epoch : 78 / 478
# combining the current components...
# Processing epoch : 79 / 478
# combining the current components...
# Processing epoch : 80 / 478
# combining the current components...
# Processing epoch : 81 / 478
# combining the current components...
# Processing epoch : 82 / 478
# combining the current components...
# Processing epoch : 83 / 478
# combining the current components...
# Processing epoch : 84 / 478
# combining the current components...
# Processing epoch : 85 / 478
# combining the current components...
# Processing epoch : 86 / 478
# combining the current components...
# Processing epoch : 87 / 478
# combining the current components...
# Processing epoch : 88 / 478
# combining the current components...
# Processing epoch : 89 / 478
# combining the current components...
# Processing epoch : 90 / 478
# combining the current components...
# Processing epoch : 91 / 478
# combining the current components...
# Processing epoch : 92 / 478
# combining the current components...
# Processing epoch : 93 / 478
# combining the current components...
# Processing epoch : 94 / 478
# combining the current components...
# Processing epoch : 95 / 478
# combining the current components...
# Processing epoch : 96 / 478
# combining the current components...
# Processing epoch : 97 / 478
# combining the current components...
# Processing epoch : 98 / 478
# combining the current components...
# Processing epoch : 99 / 478
# combining the current components...
# Processing epoch : 100 / 478
# combining the current components...
# Processing epoch : 101 / 478
# combining the current components...
# Processing epoch : 102 / 478
# combining the current components...
# Processing epoch : 103 / 478
# combining the current components...
# Processing epoch : 104 / 478
# combining the current components...
# Processing epoch : 105 / 478
# combining the current components...
# Processing epoch : 106 / 478
# combining the current components...
# Processing epoch : 107 / 478
# combining the current components...
# Processing epoch : 108 / 478
# combining the current components...
# Processing epoch : 109 / 478
# combining the current components...
# Processing epoch : 110 / 478
# combining the current components...
# Processing epoch : 111 / 478
# combining the current components...
# Processing epoch : 112 / 478
# combining the current components...
# Processing epoch : 113 / 478
# combining the current components...
# Processing epoch : 114 / 478
# combining the current components...
# Processing epoch : 115 / 478
# combining the current components...
# Processing epoch : 116 / 478
# combining the current components...
# Processing epoch : 117 / 478
# combining the current components...
# Processing epoch : 118 / 478
# combining the current components...
# Processing epoch : 119 / 478
# combining the current components...
# Processing epoch : 120 / 478
# combining the current components...
# Processing epoch : 121 / 478
# combining the current components...
# Processing epoch : 122 / 478
# combining the current components...
# Processing epoch : 123 / 478
# combining the current components...
# Processing epoch : 124 / 478
# combining the current components...
# Processing epoch : 125 / 478
# combining the current components...
# Processing epoch : 126 / 478
# combining the current components...
# Processing epoch : 127 / 478
# combining the current components...
# Processing epoch : 128 / 478
# combining the current components...
# Processing epoch : 129 / 478
# combining the current components...
# Processing epoch : 130 / 478
# combining the current components...
# Processing epoch : 131 / 478
# combining the current components...
# Processing epoch : 132 / 478
# combining the current components...
# Processing epoch : 133 / 478
# combining the current components...
# Processing epoch : 134 / 478
# combining the current components...
# Processing epoch : 135 / 478
# combining the current components...
# Processing epoch : 136 / 478
# combining the current components...
# Processing epoch : 137 / 478
# combining the current components...
# Processing epoch : 138 / 478
# combining the current components...
# Processing epoch : 139 / 478
# combining the current components...
# Processing epoch : 140 / 478
# combining the current components...
# Processing epoch : 141 / 478
# combining the current components...
# Processing epoch : 142 / 478
# combining the current components...
# Processing epoch : 143 / 478
# combining the current components...
# Processing epoch : 144 / 478
# combining the current components...
# Processing epoch : 145 / 478
# combining the current components...
# Processing epoch : 146 / 478
# combining the current components...
# Processing epoch : 147 / 478
# combining the current components...
# Processing epoch : 148 / 478
# combining the current components...
# Processing epoch : 149 / 478
# combining the current components...
# Processing epoch : 150 / 478
# combining the current components...
# Processing epoch : 151 / 478
# combining the current components...
# Processing epoch : 152 / 478
# combining the current components...
# Processing epoch : 153 / 478
# combining the current components...
# Processing epoch : 154 / 478
# combining the current components...
# Processing epoch : 155 / 478
# combining the current components...
# Processing epoch : 156 / 478
# combining the current components...
# Processing epoch : 157 / 478
# combining the current components...
# Processing epoch : 158 / 478
# combining the current components...
# Processing epoch : 159 / 478
# combining the current components...
# Processing epoch : 160 / 478
# combining the current components...
# Processing epoch : 161 / 478
# combining the current components...
# Processing epoch : 162 / 478
# combining the current components...
# Processing epoch : 163 / 478
# combining the current components...
# Processing epoch : 164 / 478
# combining the current components...
# Processing epoch : 165 / 478
# combining the current components...
# Processing epoch : 166 / 478
# combining the current components...
# Processing epoch : 167 / 478
# combining the current components...
# Processing epoch : 168 / 478
# combining the current components...
# Processing epoch : 169 / 478
# combining the current components...
# Processing epoch : 170 / 478
# combining the current components...
# Processing epoch : 171 / 478
# combining the current components...
# Processing epoch : 172 / 478
# combining the current components...
# Processing epoch : 173 / 478
# combining the current components...
# Processing epoch : 174 / 478
# combining the current components...
# Processing epoch : 175 / 478
# combining the current components...
# Processing epoch : 176 / 478
# combining the current components...
# Processing epoch : 177 / 478
# combining the current components...
# Processing epoch : 178 / 478
# combining the current components...
# Processing epoch : 179 / 478
# combining the current components...
# Processing epoch : 180 / 478
# combining the current components...
# Processing epoch : 181 / 478
# combining the current components...
# Processing epoch : 182 / 478
# combining the current components...
# Processing epoch : 183 / 478
# combining the current components...
# Processing epoch : 184 / 478
# combining the current components...
# Processing epoch : 185 / 478
# combining the current components...
# Processing epoch : 186 / 478
# combining the current components...
# Processing epoch : 187 / 478
# combining the current components...
# Processing epoch : 188 / 478
# combining the current components...
# Processing epoch : 189 / 478
# combining the current components...
# Processing epoch : 190 / 478
# combining the current components...
# Processing epoch : 191 / 478
# combining the current components...
# Processing epoch : 192 / 478
# combining the current components...
# Processing epoch : 193 / 478
# combining the current components...
# Processing epoch : 194 / 478
# combining the current components...
# Processing epoch : 195 / 478
# combining the current components...
# Processing epoch : 196 / 478
# combining the current components...
# Processing epoch : 197 / 478
# combining the current components...
# Processing epoch : 198 / 478
# combining the current components...
# Processing epoch : 199 / 478
# combining the current components...
# Processing epoch : 200 / 478
# combining the current components...
# Processing epoch : 201 / 478
# combining the current components...
# Processing epoch : 202 / 478
# combining the current components...
# Processing epoch : 203 / 478
# combining the current components...
# Processing epoch : 204 / 478
# combining the current components...
# Processing epoch : 205 / 478
# combining the current components...
# Processing epoch : 206 / 478
# combining the current components...
# Processing epoch : 207 / 478
# combining the current components...
# Processing epoch : 208 / 478
# combining the current components...
# Processing epoch : 209 / 478
# combining the current components...
# Processing epoch : 210 / 478
# combining the current components...
# Processing epoch : 211 / 478
# combining the current components...
# Processing epoch : 212 / 478
# combining the current components...
# Processing epoch : 213 / 478
# combining the current components...
# Processing epoch : 214 / 478
# combining the current components...
# Processing epoch : 215 / 478
# combining the current components...
# Processing epoch : 216 / 478
# combining the current components...
# Processing epoch : 217 / 478
# combining the current components...
# Processing epoch : 218 / 478
# combining the current components...
# Processing epoch : 219 / 478
# combining the current components...
# Processing epoch : 220 / 478
# combining the current components...
# Processing epoch : 221 / 478
# combining the current components...
# Processing epoch : 222 / 478
# combining the current components...
# Processing epoch : 223 / 478
# combining the current components...
# Processing epoch : 224 / 478
# combining the current components...
# Processing epoch : 225 / 478
# combining the current components...
# Processing epoch : 226 / 478
# combining the current components...
# Processing epoch : 227 / 478
# combining the current components...
# Processing epoch : 228 / 478
# combining the current components...
# Processing epoch : 229 / 478
# combining the current components...
# Processing epoch : 230 / 478
# combining the current components...
# Processing epoch : 231 / 478
# combining the current components...
# Processing epoch : 232 / 478
# combining the current components...
# Processing epoch : 233 / 478
# combining the current components...
# Processing epoch : 234 / 478
# combining the current components...
# Processing epoch : 235 / 478
# combining the current components...
# Processing epoch : 236 / 478
# combining the current components...
# Processing epoch : 237 / 478
# combining the current components...
# Processing epoch : 238 / 478
# combining the current components...
# Processing epoch : 239 / 478
# combining the current components...
# Processing epoch : 240 / 478
# combining the current components...
# Processing epoch : 241 / 478
# combining the current components...
# Processing epoch : 242 / 478
# combining the current components...
# Processing epoch : 243 / 478
# combining the current components...
# Processing epoch : 244 / 478
# combining the current components...
# Processing epoch : 245 / 478
# combining the current components...
# Processing epoch : 246 / 478
# combining the current components...
# Processing epoch : 247 / 478
# combining the current components...
# Processing epoch : 248 / 478
# combining the current components...
# Processing epoch : 249 / 478
# combining the current components...
# Processing epoch : 250 / 478
# combining the current components...
# Processing epoch : 251 / 478
# combining the current components...
# Processing epoch : 252 / 478
# combining the current components...
# Processing epoch : 253 / 478
# combining the current components...
# Processing epoch : 254 / 478
# combining the current components...
# Processing epoch : 255 / 478
# combining the current components...
# Processing epoch : 256 / 478
# combining the current components...
# Processing epoch : 257 / 478
# combining the current components...
# Processing epoch : 258 / 478
# combining the current components...
# Processing epoch : 259 / 478
# combining the current components...
# Processing epoch : 260 / 478
# combining the current components...
# Processing epoch : 261 / 478
# combining the current components...
# Processing epoch : 262 / 478
# combining the current components...
# Processing epoch : 263 / 478
# combining the current components...
# Processing epoch : 264 / 478
# combining the current components...
# Processing epoch : 265 / 478
# combining the current components...
# Processing epoch : 266 / 478
# combining the current components...
# Processing epoch : 267 / 478
# combining the current components...
# Processing epoch : 268 / 478
# combining the current components...
# Processing epoch : 269 / 478
# combining the current components...
# Processing epoch : 270 / 478
# combining the current components...
# Processing epoch : 271 / 478
# combining the current components...
# Processing epoch : 272 / 478
# combining the current components...
# Processing epoch : 273 / 478
# combining the current components...
# Processing epoch : 274 / 478
# combining the current components...
# Processing epoch : 275 / 478
# combining the current components...
# Processing epoch : 276 / 478
# combining the current components...
# Processing epoch : 277 / 478
# combining the current components...
# Processing epoch : 278 / 478
# combining the current components...
# Processing epoch : 279 / 478
# combining the current components...
# Processing epoch : 280 / 478
# combining the current components...
# Processing epoch : 281 / 478
# combining the current components...
# Processing epoch : 282 / 478
# combining the current components...
# Processing epoch : 283 / 478
# combining the current components...
# Processing epoch : 284 / 478
# combining the current components...
# Processing epoch : 285 / 478
# combining the current components...
# Processing epoch : 286 / 478
# combining the current components...
# Processing epoch : 287 / 478
# combining the current components...
# Processing epoch : 288 / 478
# combining the current components...
# Processing epoch : 289 / 478
# combining the current components...
# Processing epoch : 290 / 478
# combining the current components...
# Processing epoch : 291 / 478
# combining the current components...
# Processing epoch : 292 / 478
# combining the current components...
# Processing epoch : 293 / 478
# combining the current components...
# Processing epoch : 294 / 478
# combining the current components...
# Processing epoch : 295 / 478
# combining the current components...
# Processing epoch : 296 / 478
# combining the current components...
# Processing epoch : 297 / 478
# combining the current components...
# Processing epoch : 298 / 478
# combining the current components...
# Processing epoch : 299 / 478
# combining the current components...
# Processing epoch : 300 / 478
# combining the current components...
# Processing epoch : 301 / 478
# combining the current components...
# Processing epoch : 302 / 478
# combining the current components...
# Processing epoch : 303 / 478
# combining the current components...
# Processing epoch : 304 / 478
# combining the current components...
# Processing epoch : 305 / 478
# combining the current components...
# Processing epoch : 306 / 478
# combining the current components...
# Processing epoch : 307 / 478
# combining the current components...
# Processing epoch : 308 / 478
# combining the current components...
# Processing epoch : 309 / 478
# combining the current components...
# Processing epoch : 310 / 478
# combining the current components...
# Processing epoch : 311 / 478
# combining the current components...
# Processing epoch : 312 / 478
# combining the current components...
# Processing epoch : 313 / 478
# combining the current components...
# Processing epoch : 314 / 478
# combining the current components...
# Processing epoch : 315 / 478
# combining the current components...
# Processing epoch : 316 / 478
# combining the current components...
# Processing epoch : 317 / 478
# combining the current components...
# Processing epoch : 318 / 478
# combining the current components...
# Processing epoch : 319 / 478
# combining the current components...
# Processing epoch : 320 / 478
# combining the current components...
# Processing epoch : 321 / 478
# combining the current components...
# Processing epoch : 322 / 478
# combining the current components...
# Processing epoch : 323 / 478
# combining the current components...
# Processing epoch : 324 / 478
# combining the current components...
# Processing epoch : 325 / 478
# combining the current components...
# Processing epoch : 326 / 478
# combining the current components...
# Processing epoch : 327 / 478
# combining the current components...
# Processing epoch : 328 / 478
# combining the current components...
# Processing epoch : 329 / 478
# combining the current components...
# Processing epoch : 330 / 478
# combining the current components...
# Processing epoch : 331 / 478
# combining the current components...
# Processing epoch : 332 / 478
# combining the current components...
# Processing epoch : 333 / 478
# combining the current components...
# Processing epoch : 334 / 478
# combining the current components...
# Processing epoch : 335 / 478
# combining the current components...
# Processing epoch : 336 / 478
# combining the current components...
# Processing epoch : 337 / 478
# combining the current components...
# Processing epoch : 338 / 478
# combining the current components...
# Processing epoch : 339 / 478
# combining the current components...
# Processing epoch : 340 / 478
# combining the current components...
# Processing epoch : 341 / 478
# combining the current components...
# Processing epoch : 342 / 478
# combining the current components...
# Processing epoch : 343 / 478
# combining the current components...
# Processing epoch : 344 / 478
# combining the current components...
# Processing epoch : 345 / 478
# combining the current components...
# Processing epoch : 346 / 478
# combining the current components...
# Processing epoch : 347 / 478
# combining the current components...
# Processing epoch : 348 / 478
# combining the current components...
# Processing epoch : 349 / 478
# combining the current components...
# Processing epoch : 350 / 478
# combining the current components...
# Processing epoch : 351 / 478
# combining the current components...
# Processing epoch : 352 / 478
# combining the current components...
# Processing epoch : 353 / 478
# combining the current components...
# Processing epoch : 354 / 478
# combining the current components...
# Processing epoch : 355 / 478
# combining the current components...
# Processing epoch : 356 / 478
# combining the current components...
# Processing epoch : 357 / 478
# combining the current components...
# Processing epoch : 358 / 478
# combining the current components...
# Processing epoch : 359 / 478
# combining the current components...
# Processing epoch : 360 / 478
# combining the current components...
# Processing epoch : 361 / 478
# combining the current components...
# Processing epoch : 362 / 478
# combining the current components...
# Processing epoch : 363 / 478
# combining the current components...
# Processing epoch : 364 / 478
# combining the current components...
# Processing epoch : 365 / 478
# combining the current components...
# Processing epoch : 366 / 478
# combining the current components...
# Processing epoch : 367 / 478
# combining the current components...
# Processing epoch : 368 / 478
# combining the current components...
# Processing epoch : 369 / 478
# combining the current components...
# Processing epoch : 370 / 478
# combining the current components...
# Processing epoch : 371 / 478
# combining the current components...
# Processing epoch : 372 / 478
# combining the current components...
# Processing epoch : 373 / 478
# combining the current components...
# Processing epoch : 374 / 478
# combining the current components...
# Processing epoch : 375 / 478
# combining the current components...
# Processing epoch : 376 / 478
# combining the current components...
# Processing epoch : 377 / 478
# combining the current components...
# Processing epoch : 378 / 478
# combining the current components...
# Processing epoch : 379 / 478
# combining the current components...
# Processing epoch : 380 / 478
# combining the current components...
# Processing epoch : 381 / 478
# combining the current components...
# Processing epoch : 382 / 478
# combining the current components...
# Processing epoch : 383 / 478
# combining the current components...
# Processing epoch : 384 / 478
# combining the current components...
# Processing epoch : 385 / 478
# combining the current components...
# Processing epoch : 386 / 478
# combining the current components...
# Processing epoch : 387 / 478
# combining the current components...
# Processing epoch : 388 / 478
# combining the current components...
# Processing epoch : 389 / 478
# combining the current components...
# Processing epoch : 390 / 478
# combining the current components...
# Processing epoch : 391 / 478
# combining the current components...
# Processing epoch : 392 / 478
# combining the current components...
# Processing epoch : 393 / 478
# combining the current components...
# Processing epoch : 394 / 478
# combining the current components...
# Processing epoch : 395 / 478
# combining the current components...
# Processing epoch : 396 / 478
# combining the current components...
# Processing epoch : 397 / 478
# combining the current components...
# Processing epoch : 398 / 478
# combining the current components...
# Processing epoch : 399 / 478
# combining the current components...
# Processing epoch : 400 / 478
# combining the current components...
# Processing epoch : 401 / 478
# combining the current components...
# Processing epoch : 402 / 478
# combining the current components...
# Processing epoch : 403 / 478
# combining the current components...
# Processing epoch : 404 / 478
# combining the current components...
# Processing epoch : 405 / 478
# combining the current components...
# Processing epoch : 406 / 478
# combining the current components...
# Processing epoch : 407 / 478
# combining the current components...
# Processing epoch : 408 / 478
# combining the current components...
# Processing epoch : 409 / 478
# combining the current components...
# Processing epoch : 410 / 478
# combining the current components...
# Processing epoch : 411 / 478
# combining the current components...
# Processing epoch : 412 / 478
# combining the current components...
# Processing epoch : 413 / 478
# combining the current components...
# Processing epoch : 414 / 478
# combining the current components...
# Processing epoch : 415 / 478
# combining the current components...
# Processing epoch : 416 / 478
# combining the current components...
# Processing epoch : 417 / 478
# combining the current components...
# Processing epoch : 418 / 478
# combining the current components...
# Processing epoch : 419 / 478
# combining the current components...
# Processing epoch : 420 / 478
# combining the current components...
# Processing epoch : 421 / 478
# combining the current components...
# Processing epoch : 422 / 478
# combining the current components...
# Processing epoch : 423 / 478
# combining the current components...
# Processing epoch : 424 / 478
# combining the current components...
# Processing epoch : 425 / 478
# combining the current components...
# Processing epoch : 426 / 478
# combining the current components...
# Processing epoch : 427 / 478
# combining the current components...
# Processing epoch : 428 / 478
# combining the current components...
# Processing epoch : 429 / 478
# combining the current components...
# Processing epoch : 430 / 478
# combining the current components...
# Processing epoch : 431 / 478
# combining the current components...
# Processing epoch : 432 / 478
# combining the current components...
# Processing epoch : 433 / 478
# combining the current components...
# Processing epoch : 434 / 478
# combining the current components...
# Processing epoch : 435 / 478
# combining the current components...
# Processing epoch : 436 / 478
# combining the current components...
# Processing epoch : 437 / 478
# combining the current components...
# Processing epoch : 438 / 478
# combining the current components...
# Processing epoch : 439 / 478
# combining the current components...
# Processing epoch : 440 / 478
# combining the current components...
# Processing epoch : 441 / 478
# combining the current components...
# Processing epoch : 442 / 478
# combining the current components...
# Processing epoch : 443 / 478
# combining the current components...
# Processing epoch : 444 / 478
# combining the current components...
# Processing epoch : 445 / 478
# combining the current components...
# Processing epoch : 446 / 478
# combining the current components...
# Processing epoch : 447 / 478
# combining the current components...
# Processing epoch : 448 / 478
# combining the current components...
# Processing epoch : 449 / 478
# combining the current components...
# Processing epoch : 450 / 478
# combining the current components...
# Processing epoch : 451 / 478
# combining the current components...
# Processing epoch : 452 / 478
# combining the current components...
# Processing epoch : 453 / 478
# combining the current components...
# Processing epoch : 454 / 478
# combining the current components...
# Processing epoch : 455 / 478
# combining the current components...
# Processing epoch : 456 / 478
# combining the current components...
# Processing epoch : 457 / 478
# combining the current components...
# Processing epoch : 458 / 478
# combining the current components...
# Processing epoch : 459 / 478
# combining the current components...
# Processing epoch : 460 / 478
# combining the current components...
# Processing epoch : 461 / 478
# combining the current components...
# Processing epoch : 462 / 478
# combining the current components...
# Processing epoch : 463 / 478
# combining the current components...
# Processing epoch : 464 / 478
# combining the current components...
# Processing epoch : 465 / 478
# combining the current components...
# Processing epoch : 466 / 478
# combining the current components...
# Processing epoch : 467 / 478
# combining the current components...
# Processing epoch : 468 / 478
# combining the current components...
# Processing epoch : 469 / 478
# combining the current components...
# Processing epoch : 470 / 478
# combining the current components...
# Processing epoch : 471 / 478
# combining the current components...
# Processing epoch : 472 / 478
# combining the current components...
# Processing epoch : 473 / 478
# combining the current components...
# Processing epoch : 474 / 478
# combining the current components...
# Processing epoch : 475 / 478
# combining the current components...
# Processing epoch : 476 / 478
# combining the current components...
# Processing epoch : 477 / 478
# combining the current components...
# Processing epoch : 478 / 478
# combining the current components...
# [done]
# Reading labels from parcellation...
#    read 34 labels from /Users/lina_01/Desktop/sub-032302/label/lh.aparc.annot
#    read 34 labels from /Users/lina_01/Desktop/sub-032302/label/rh.aparc.annot
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# ...
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Extracting time courses for 68 labels (mode: mean_flip)
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# Maximum iterations reached. 0 of 1 converged
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 62
#      55 m = Multitaper(time_series=np.array(label_ts)[inds].transpose(2, 0, 1),
#      56     sampling_frequency=250)
#      58 c = Connectivity(fourier_coefficients=m.fft(),
#      59         frequencies=m.frequencies,
#      60         time=m.time)
# ---> 62 con = getattr(c, 'generalized_partial_directed_coherence')()
#      63 mat = np.nan_to_num(con.squeeze())
#      64 mats.append(mat[8:14,:,:])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/spectral_connectivity/connectivity.py:61, in _asnumpy.<locals>.wrapper(*args, **kwargs)
#      59 @wraps(connectivity_measure)
#      60 def wrapper(*args, **kwargs):
# ---> 61     measure = connectivity_measure(*args, **kwargs)
#      62     if measure is not None:
#      63         try:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/spectral_connectivity/connectivity.py:871, in Connectivity.generalized_partial_directed_coherence(self)
#     847 """The transfer function coupling strength normalized by its
#     848 strength of coupling to other signals (outflow).
#     849
#    (...)
#     867
#     868 """
#     869 noise_variance = _get_noise_variance(self._noise_covariance)
#     870 return _squared_magnitude(
# --> 871     self._MVAR_Fourier_coefficients
#     872     / xp.sqrt(noise_variance)
#     873     / _total_outflow(self._MVAR_Fourier_coefficients, noise_variance)
#     874 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/spectral_connectivity/connectivity.py:274, in Connectivity._MVAR_Fourier_coefficients(self)
#     272 @property
#     273 def _MVAR_Fourier_coefficients(self):
# --> 274     return xp.linalg.inv(self._transfer_function)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/spectral_connectivity/connectivity.py:79, in _non_negative_frequencies.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      77 @wraps(connectivity_measure)
#      78 def wrapper(*args, **kwargs):
# ---> 79     measure = connectivity_measure(*args, **kwargs)
#      80     if measure is not None:
#      81         n_frequencies = measure.shape[axis]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/spectral_connectivity/connectivity.py:266, in Connectivity._transfer_function(self)
#     263 @property
#     264 @_non_negative_frequencies(axis=-3)
#     265 def _transfer_function(self):
# --> 266     return _estimate_transfer_function(self._minimum_phase_factor)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/spectral_connectivity/connectivity.py:261, in Connectivity._minimum_phase_factor(self)
#     259 @property
#     260 def _minimum_phase_factor(self):
# --> 261     return minimum_phase_decomposition(self._expectation_cross_spectral_matrix())
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/spectral_connectivity/minimum_phase_decomposition.py:200, in minimum_phase_decomposition(cross_spectral_matrix, tolerance, max_iterations)
#     194 logger.debug(
#     195     "iteration: {0}, {1} of {2} converged".format(
#     196         iteration, is_converged.sum(), len(is_converged)
#     197     )
#     198 )
#     199 old_minimum_phase_factor = minimum_phase_factor.copy()
# --> 200 linear_predictor = _get_linear_predictor(
#     201     minimum_phase_factor, cross_spectral_matrix, I
#     202 )
#     203 minimum_phase_factor = xp.matmul(
#     204     minimum_phase_factor, _get_causal_signal(linear_predictor)
#     205 )
#     207 # If already converged at a time point, don't change.
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/spectral_connectivity/minimum_phase_decomposition.py:152, in _get_linear_predictor(minimum_phase_factor, cross_spectral_matrix, I)
#     128 def _get_linear_predictor(minimum_phase_factor, cross_spectral_matrix, I):
#     129     """Measure how close the minimum phase factor is to the original
#     130     cross spectral matrix.
#     131
#    (...)
#     150
#     151     """
# --> 152     covariance_sandwich_estimator = xp.linalg.solve(
#     153         minimum_phase_factor, cross_spectral_matrix
#     154     )
#     155     covariance_sandwich_estimator = xp.linalg.solve(
#     156         minimum_phase_factor, _conjugate_transpose(covariance_sandwich_estimator)
#     157     )
#     158     return covariance_sandwich_estimator + I
#
# File <__array_function__ internals>:180, in solve(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/linalg/linalg.py:400, in solve(a, b)
#     398 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     399 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 400 r = gufunc(a, b, signature=signature, extobj=extobj)
#     402 return wrap(r.astype(result_t, copy=False))
#
# KeyboardInterrupt:
