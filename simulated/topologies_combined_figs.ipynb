# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
figures = ['sim_topo_func_comm_non_dyn.png','sim_topo_func_comm_dyn.png']
margin = 10
fig, axes = plt.subplots(1, 2, figsize=(5,6))
for figure, ax in zip(figures, axes.ravel()):
    img = mpimg.imread(f"{figure}")
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    ax.set(frame_on=False)
    
    ax.imshow(img)        
    #ax.set_aspect(1)    

#fig.tight_layout(rect=[-0.01, -0.01, .01, .01], w_pad=0.0, h_pad=0.0)
plt.subplots_adjust(wspace=0, hspace=0)

fig.suptitle('Common input \n', fontsize=10)
fig.tight_layout(pad=0)
fig.savefig("fig_topo_comm_func.png", bbox_inches='tight',dpi=300)

# %%
figures = ['sim_topo_func_ind_non_dyn.png','sim_topo_func_ind_dyn.png']
margin = 10
fig, axes = plt.subplots(1, 2, figsize=(5,6))
for figure, ax in zip(figures, axes.ravel()):
    img = mpimg.imread(f"{figure}")
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    ax.set(frame_on=False)
    
    ax.imshow(img)        
    #ax.set_aspect(1)    

#fig.tight_layout(rect=[-0.01, -0.01, .01, .01], w_pad=0.0, h_pad=0.0)
plt.subplots_adjust(wspace=0, hspace=0)

fig.suptitle('Indirect connection\n', fontsize=10)
fig.tight_layout(pad=0)
fig.savefig("fig_topo_ind_func.png", bbox_inches='tight',dpi=300)

# %%
figures = ['sim_topo_func_vol_non_dyn.png','sim_topo_func_vol_dyn.png']
margin = 10
fig, axes = plt.subplots(1, 2, figsize=(5,6))
for figure, ax in zip(figures, axes.ravel()):
    img = mpimg.imread(f"{figure}")
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    ax.set(frame_on=False)
    
    ax.imshow(img)        
    #ax.set_aspect(1)    

#fig.tight_layout(rect=[-0.01, -0.01, .01, .01], w_pad=0.0, h_pad=0.0)
plt.subplots_adjust(wspace=0, hspace=0)

fig.suptitle('Volume conduction \n', fontsize=10)
fig.tight_layout(pad=0)
fig.savefig("fig_topo_vol_func.png", bbox_inches='tight',dpi=300)

# %%
figures = ['sim_topo_eff_comm_non_dyn.png','sim_topo_eff_comm_dyn.png']
margin = 10
fig, axes = plt.subplots(1, 2, figsize=(5,6))
for figure, ax in zip(figures, axes.ravel()):
    img = mpimg.imread(f"{figure}")
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    ax.set(frame_on=False)
    
    ax.imshow(img)        
    #ax.set_aspect(1)    

#fig.tight_layout(rect=[-0.01, -0.01, .01, .01], w_pad=0.0, h_pad=0.0)
plt.subplots_adjust(wspace=0, hspace=0)

fig.suptitle('Common input\n', fontsize=10)
fig.tight_layout(pad=0)
fig.savefig("fig_topo_comm_eff.png", bbox_inches='tight',dpi=300)

# %%
figures = ['sim_topo_eff_ind_non_dyn.png','sim_topo_eff_ind_dyn.png']
margin = 10
fig, axes = plt.subplots(1, 2, figsize=(5,6))
for figure, ax in zip(figures, axes.ravel()):
    img = mpimg.imread(f"{figure}")
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    ax.set(frame_on=False)
    
    ax.imshow(img)        
    #ax.set_aspect(1)    

#fig.tight_layout(rect=[-0.01, -0.01, .01, .01], w_pad=0.0, h_pad=0.0)
plt.subplots_adjust(wspace=0, hspace=0)

fig.suptitle('Indirect connection\n', fontsize=10)
fig.tight_layout(pad=0)
fig.savefig("fig_topo_ind_eff.png", bbox_inches='tight',dpi=300)

# %%
figures = ['sim_topo_eff_vol_non_dyn.png','sim_topo_eff_vol_dyn.png']
margin = 10
fig, axes = plt.subplots(1, 2, figsize=(5,6))
for figure, ax in zip(figures, axes.ravel()):
    img = mpimg.imread(f"{figure}")
    ax.axes.xaxis.set_visible(False)
    ax.axes.yaxis.set_visible(False)
    ax.set(frame_on=False)
    
    ax.imshow(img)        
    #ax.set_aspect(1)    

#fig.tight_layout(rect=[-0.01, -0.01, .01, .01], w_pad=0.0, h_pad=0.0)
plt.subplots_adjust(wspace=0, hspace=0)

fig.suptitle('Volume conduction\n', fontsize=10)
fig.tight_layout(pad=0)
fig.savefig("fig_topo_vol_eff.png", bbox_inches='tight',dpi=300)
